# %%
import NanobodyPaperPlotting
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings

expressionLims = (10**0.25, 10**3)
BDFPPositiveBDFPSSCLims = (10**-1, 10**3)
BDFPNegativeBDFPSSCLims = (10**-4, 10**1)
expressionLims_kde = (0.25, 3)
# BDFPPositiveBDFPSSCLims_kde = (-1, 3)
BDFPPositiveBDFPSSCLims_kde = (0, 3)
BDFPNegativeBDFPSSCLims_kde = (-4, 1)

colors_decimal = [[120/255, 120/255, 120/255], [249/255, 29/255, 0/255], [32/255, 25/255, 250/255]]
colors_decimal_darker = [[50/255, 50/255, 50/255], [162/255, 19/255, 0/255], [25/255, 19/255, 192/255]] # 2+, 3, 2 "tint"s darker according to adobe color
colors_lightGrey = [[255/255, 255/255, 255/255], [249/255, 29/255, 0/255], [32/255, 25/255, 250/255]]

# %%
mEos1xFiles = [#("Control", ["data/mEosValency/exported_plate1/A1.fcs"]),
                ("Control", ["data/mEosValency/exported_plate2/G1.fcs"]),
                ("1x mEosNb", ["data/mEosValency/exported_plate2/G1.fcs"]),
                ("2x mEosNb", ["data/mEosValency/exported_plate2/H1.fcs"]),
                ("3x mEosNb", ["data/mEosValency/exported_plate3/A1.fcs"]),
                ("4x mEosNb", ["data/mEosValency/exported_plate3/B1.fcs"]),
                ("5x mEosNb", ["data/mEosValency/exported_plate3/C1.fcs"]),
                ("6x mEosNb", ["data/mEosValency/exported_plate3/D1.fcs"]),
              ]

mEos2xFiles = [#("Control", ["data/mEosValency/exported_plate1/A2.fcs"]),
                ("Control", ["data/mEosValency/exported_plate2/G2.fcs"]),
                ("1x mEosNb", ["data/mEosValency/exported_plate2/G2.fcs"]),
                ("2x mEosNb", ["data/mEosValency/exported_plate2/H2.fcs"]),
                ("3x mEosNb", ["data/mEosValency/exported_plate3/A2.fcs"]),
                ("4x mEosNb", ["data/mEosValency/exported_plate3/B2.fcs"]),
                ("5x mEosNb", ["data/mEosValency/exported_plate3/C2.fcs"]),
                ("6x mEosNb", ["data/mEosValency/exported_plate3/D2.fcs"]),
              ]

mEos3xFiles = [#("Control", ["data/mEosValency/exported_plate1/A3.fcs"]),
                ("Control", ["data/mEosValency/exported_plate2/G3.fcs"]),
                ("1x mEosNb", ["data/mEosValency/exported_plate2/G3.fcs"]),
                ("2x mEosNb", ["data/mEosValency/exported_plate2/H3.fcs"]),
                ("3x mEosNb", ["data/mEosValency/exported_plate3/A3.fcs"]),
                ("4x mEosNb", ["data/mEosValency/exported_plate3/B3.fcs"]),
                ("5x mEosNb", ["data/mEosValency/exported_plate3/C3.fcs"]),
                ("6x mEosNb", ["data/mEosValency/exported_plate3/D3.fcs"]),
              ]

mEos4xFiles = [#("Control", ["data/mEosValency/exported_plate1/A4.fcs"]),
                ("Control", ["data/mEosValency/exported_plate2/G4.fcs"]),
                ("1x mEosNb", ["data/mEosValency/exported_plate2/G4.fcs"]),
                ("2x mEosNb", ["data/mEosValency/exported_plate2/H4.fcs"]),
                ("3x mEosNb", ["data/mEosValency/exported_plate3/A4.fcs"]),
                ("4x mEosNb", ["data/mEosValency/exported_plate3/B4.fcs"]),
                ("5x mEosNb", ["data/mEosValency/exported_plate3/C4.fcs"]),
                ("6x mEosNb", ["data/mEosValency/exported_plate3/D4.fcs"]),
              ]

# %%
def reformatAxs(axs):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        for i, row in enumerate(axs):
            for j, ax in enumerate(row):
                ax.xaxis.set_label_coords(0.5, -0.25)
                ax.yaxis.set_label_coords(-0.2, 0.5)
        
                ax.tick_params(axis='both', which='major', pad=1, width=0.5, length=2.5) #default length is 3.5
                # ax.minorticks_off()
                ax.tick_params(axis='both', which='minor', width=0.5, length=1.5)           #default length is 2
                ax.xaxis.set_ticklabels(ax.xaxis.get_ticklabels(), fontsize=tickFontSize)
                ax.yaxis.set_ticklabels(ax.yaxis.get_ticklabels(), fontsize=tickFontSize)
                
                for spine in ax.spines.values():
                    spine.set_linewidth(0.5)

# %%
#labels are listed from low to high priority. Python3.something made a change that maintains dictionary order, so this is safe.
mEos4x_standardPoints = {
    2: [
    [15,-0.2],
    [15,0.15],
    [50,0.35],
    [400,0.5],
    [900,0.55],
    [2000,0.57],
    [2000,-0.2]
],
    
    1: [
    [10,0.45],
    [100, 0.60],
    [500, 0.7],
    [20000, 0.75],
    [20000, 1.5],
    [10, 1.5]
    ]
}

#labels are listed from low to high priority. Python3.something made a change that maintains dictionary order, so this is safe.
mEos4x_Nb6x_points = {    
    2: [ #different from standard
    [15,-0.2],
    [15,0.1],
    [50,0.29],
    [400,0.45],
    [900,0.46],
    [20000,0.47],
    [20000,-0.2]
    ],

    1: [[point[0], point[1] - 0.05] for point in mEos4x_standardPoints[1]]
}

mEos4x_Nb3x_points = {    
    2:mEos4x_standardPoints[2],
    # 2: [
    # [15,-0.2],
    # [15,0.15],
    # [50,0.35],
    # [400,0.5],
    # [900,0.55],
    # [2000,0.57],
    # [2000,-0.2]
    # ],

    1:[[point[0], point[1] - 0.05] for point in mEos4x_standardPoints[1]]
    # 1: [
    # [10,0.45 - 0.05],
    # [100, 0.60 - 0.05],
    # [500, 0.7 - 0.05],
    # [20000, 0.75 - 0.05],
    # [20000, 1.5 - 0.05],
    # [10, 1.5 - 0.05]
    # ]
}

mEos4x_Nb2x_points = {    
    2: [#different from standard
    [30,-0.2],
    [30,0.15],
    [70,0.28],
    [400,0.5],
    [900,0.55],
    [2000,0.57],
    [2000,-0.2]
    ],
    
    1: [ #different from standard
    [80,0.4],
    [300, 0.5],
    [20000, 0.75],
    [20000, 1.5],
    [80, 1.5]
    ]
}

# %%
mEos3x_standardPoints = {

    2: [
    [20,-0.2],
    [20,0.14],
    [70,0.30],
    [400,0.44],
    [900,0.49],
    [2000,0.53],
    [2000,-0.2]
    ],

    1: [
    [20, 0.42],
    [100, 0.53],
    [500, 0.65],
    [20000, 0.65],
    [20000, 1.5],
    [20, 1.5],
    ]
}

mEos3x_Nb2x_points = {
    2: [
    [40,-0.2],
    [40,0.14],
    [70,0.24],
    [400,0.37],
    [900,0.43],
    [2000,0.48],
    [2000,-0.2]
    ],

    1:[
    [70, 0.33],
    [100, 0.37],
    [500, 0.43],
    [20000, 0.43],
    [20000, 1.5],
    [70, 1.5],
    ]
}

mEos3x_Nb3x_points = {
    2: mEos3x_standardPoints[2],

    1:[[point[0], point[1] - 0.05] for point in mEos3x_standardPoints[1]]
}

mEos3x_Nb6x_points = {
    2: [
    [30,-0.2],
    [30,0.15],
    [70,0.27],
    [400,0.41],
    [900,0.5],
    [2000,0.53],
    [2000,-0.2]  
    ],

    1: [
    [20, 0.42],
    [100, 0.53],
    [500, 0.65],
    [20000, 0.65],
    [20000, 1.5],
    [20, 1.5],
    ]
}

# %%
mEos2x_standardPoints = {
    2: [   
    [20,-0.2],
    [20,0.11],
    [50,0.20],
    [400,0.32],
    [2000,0.38],
    [2000,-0.2]
    ],
    1: [
    [30, 0.33],
    [100, 0.41],
    [500, 0.53],
    [20000, 0.53],
    [20000, 1.5],
    [30, 1.5],
    ]
}


mEos2x_Nb3x_points = {
    2: [
    [25,-0.2],
    [25,0.10],
    [50,0.17],
    [400,0.29],
    [2000,0.33],
    [2000,-0.2]
    ],
    # 1: [ #removed because the microscopy was inconclusive on puncta
    # [50, 0.29],
    # [100, 0.32],
    # [500, 0.34],
    # [20000, 0.37],
    # [20000, 1.5],
    # [50, 1.5],
    # ]
}

mEos2x_Nb4x_points = {
    2: [
    [25,-0.2],
    [25,0.10],
    [50,0.17],
    [400,0.29],
    [2000,0.33],
    [2000,-0.2]
    ],
    1: [
    [40, 0.31],
    [100, 0.38],
    [400, 0.43],
    [20000, 0.51],
    [20000, 1.5],
    [40, 1.5],
    ]

}

# %%
mEos1x_perPlotBoundaries = {
    "Control": {},
    "1x mEosNb": {},
    "2x mEosNb": {},
    "3x mEosNb": {},
    "4x mEosNb": {},
    "5x mEosNb": {},
    "6x mEosNb": {}
}

mEos2x_perPlotBoundaries = {
    "Control": {},
    "1x mEosNb": {},
    "2x mEosNb": {},
    "3x mEosNb": mEos2x_Nb3x_points,
    "4x mEosNb": mEos2x_Nb4x_points,
    "5x mEosNb": mEos2x_standardPoints,
    "6x mEosNb": mEos2x_standardPoints   
}

mEos3x_perPlotBoundaries = {
    "Control": {},
    "1x mEosNb": {},
    "2x mEosNb": mEos3x_Nb2x_points,
    "3x mEosNb": mEos3x_Nb3x_points,
    "4x mEosNb": mEos3x_standardPoints,
    "5x mEosNb": mEos3x_standardPoints,
    "6x mEosNb": mEos3x_Nb6x_points   
}

mEos4x_perPlotBoundaries = {
    "Control": {},
    "1x mEosNb": {},
    "2x mEosNb": mEos4x_Nb2x_points,
    "3x mEosNb": mEos4x_Nb3x_points,
    "4x mEosNb": mEos4x_standardPoints,
    "5x mEosNb": mEos4x_standardPoints,
    "6x mEosNb": mEos4x_Nb6x_points   
}

# %%
mEos1xData = []
for title, files in mEos1xFiles:
    data = NanobodyPaperPlotting.readDataFromFilelist(files)
    data, _ = NanobodyPaperPlotting.gateBDFP(data, title)
    data = NanobodyPaperPlotting.labelFromPathPoints(data, mEos1x_perPlotBoundaries[title])
    mEos1xData.append((title, data))

mEos2xData = []
for title, files in mEos2xFiles:
    data = NanobodyPaperPlotting.readDataFromFilelist(files)
    data, _ = NanobodyPaperPlotting.gateBDFP(data, title)
    data = NanobodyPaperPlotting.labelFromPathPoints(data, mEos2x_perPlotBoundaries[title])
    mEos2xData.append((title, data))

mEos3xData = []
for title, files in mEos3xFiles:
    data = NanobodyPaperPlotting.readDataFromFilelist(files)
    data, _ = NanobodyPaperPlotting.gateBDFP(data, title)
    data = NanobodyPaperPlotting.labelFromPathPoints(data, mEos3x_perPlotBoundaries[title])
    mEos3xData.append((title, data))

mEos4xData = []
for title, files in mEos4xFiles:
    data = NanobodyPaperPlotting.readDataFromFilelist(files)
    data, _ = NanobodyPaperPlotting.gateBDFP(data, title)
    data = NanobodyPaperPlotting.labelFromPathPoints(data, mEos4x_perPlotBoundaries[title])
    mEos4xData.append((title, data))

# %%
# # squarePlotSize = 3


# # squarePlotSize = 5/8 #5/8 of inch in final printed version NOTE: this doesn't account for margins, so this should probably be changed entirely
# fontSize=5
# plt.rcParams.update({'font.size': fontSize})

# numCols = 7
# numRows = 4

# DAmFRETFig = plt.Figure((squarePlotSize*numCols ,squarePlotSize*numRows), dpi=300)
# DAmFRETAxs = DAmFRETFig.subplots(numRows,numCols, subplot_kw={'projection': "scatter_density"})
# NanobodyPaperPlotting.DAmFRETRowFromData(mEos1xData, DAmFRETAxs[0], addTitles=True, rowTitle="1x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, rowTitleSize=fontSize)
# NanobodyPaperPlotting.DAmFRETRowFromData(mEos2xData, DAmFRETAxs[1], addTitles=False, rowTitle="2x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, rowTitleSize=fontSize)
# NanobodyPaperPlotting.DAmFRETRowFromData(mEos3xData, DAmFRETAxs[2], addTitles=False, rowTitle="3x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, rowTitleSize=fontSize)
# NanobodyPaperPlotting.DAmFRETRowFromData(mEos4xData, DAmFRETAxs[3], addTitles=False, rowTitle="4x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, rowTitleSize=fontSize)
# DAmFRETFig.tight_layout(pad=0.15)
# plt.show()
# # DAmFRETFig.savefig("plots/valencySeries_DAmFRET_SMALLER.png")
# DAmFRETFig

# %%
squarePlotSize = 5/8 #5/8 of inch in final printed version NOTE: this doesn't account for margins, so this should probably be changed entirely
fontSize = 6 #changed from 7 
tickFontSize = 4
plt.rcParams.update({'font.size': fontSize})

numCols = 7
numRows = 4

# DAmFRETFig = plt.Figure((squarePlotSize*numCols ,squarePlotSize*numRows), dpi=300)
DAmFRETFig = plt.Figure((6.5,4), dpi=300)
DAmFRETAxs = DAmFRETFig.subplots(numRows,numCols, subplot_kw={'projection': "scatter_density"})

NanobodyPaperPlotting.DAmFRETRowFromData(mEos1xData, DAmFRETAxs[0], addTitles=False, firstColLabelsOnly=True, addXLabels=False, mpl_dpi=200)
NanobodyPaperPlotting.DAmFRETRowFromData(mEos2xData, DAmFRETAxs[1], addTitles=False, firstColLabelsOnly=True, addXLabels=False, mpl_dpi=200)
NanobodyPaperPlotting.DAmFRETRowFromData(mEos3xData, DAmFRETAxs[2], addTitles=False, firstColLabelsOnly=True, addXLabels=False, mpl_dpi=200)
NanobodyPaperPlotting.DAmFRETRowFromData(mEos4xData, DAmFRETAxs[3], addTitles=False, firstColLabelsOnly=True, addXLabels=True, mpl_dpi=200)

reformatAxs(DAmFRETAxs)

    
DAmFRETFig.tight_layout(pad=0.25)
plt.show()
# DAmFRETFig.savefig("plots/valencySeries_DAmFRET.png", bbox_inches="tight")
DAmFRETFig

# %%
# contourPopFig = plt.Figure((squarePlotSize*numCols ,squarePlotSize*numRows), dpi=300)
# contourPopAxs = contourPopFig.subplots(numRows,numCols, subplot_kw={'projection': "scatter_density"})

contourPopFig = plt.Figure((6.5,4), dpi=300)
contourPopAxs = contourPopFig.subplots(numRows,numCols-1, subplot_kw={'projection': "scatter_density"})


textX = 0.03
textYMax = 0.97

NanobodyPaperPlotting.populationRowWithDensityContourFromData(mEos1xData[1:], contourPopAxs[0], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=textX, textYMax=textYMax)
NanobodyPaperPlotting.populationRowWithDensityContourFromData(mEos2xData[1:], contourPopAxs[1], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=textX, textYMax=textYMax)
NanobodyPaperPlotting.populationRowWithDensityContourFromData(mEos3xData[1:], contourPopAxs[2], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=textX, textYMax=textYMax)
NanobodyPaperPlotting.populationRowWithDensityContourFromData(mEos4xData[1:], contourPopAxs[3], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=True, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=textX, textYMax=textYMax)

for ax in contourPopAxs[3]:
    ax.set_xlabel("mEos3 conc. (p.d.u.)")

reformatAxs(contourPopAxs)
contourPopFig.tight_layout(pad=0.25)
# contourPopFig.savefig("plots/valencySeries_populationWithContour.png", bbox_inches="tight")
contourPopFig

# %%
# for ax in contourPopAxs[3]:
#     ax.set_xlabel("mEos3 conc. (p.d.u.)")

# reformatAxs(contourPopAxs)
# contourPopFig.tight_layout(pad=0.25)
# # contourPopFig.savefig("plots/valencySeries_populationWithContour_SMALLER.png")
# contourPopFig

# %%
# contourPopFig.savefig("test_valencySmall_pops.png")

# %%
# #TESTING!!!

# # contourPopFig = plt.Figure((squarePlotSize*numCols ,squarePlotSize*numRows), dpi=300)
# # contourPopAxs = contourPopFig.subplots(numRows,numCols, subplot_kw={'projection': "scatter_density"})

# contourPopFig = plt.Figure((6.5,4), dpi=300)
# contourPopAxs = contourPopFig.subplots(numRows,numCols-1, subplot_kw={'projection': "scatter_density"})

# NanobodyPaperPlotting.populationRowFromData(mEos1xData[1:], contourPopAxs[0], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=0.03, textYMax=0.97)
# NanobodyPaperPlotting.populationRowFromData(mEos2xData[1:], contourPopAxs[1], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=0.03, textYMax=0.97)
# NanobodyPaperPlotting.populationRowFromData(mEos3xData[1:], contourPopAxs[2], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=False, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=0.03, textYMax=0.97)
# NanobodyPaperPlotting.populationRowFromData(mEos4xData[1:], contourPopAxs[3], "manualLabel", addTitles=False, firstColLabelsOnly=True, addXLabels=True, labelOrder=[1,0,2], mpl_dpi=200, summaryFontSize=tickFontSize, textX=0.03, textYMax=0.97)

# reformatAxs(contourPopAxs)
# contourPopFig.tight_layout(pad=0.25)
# # contourPopFig.savefig("plots/valencySeries_population_SMALLER.png")
# contourPopFig

# %%
#attempt to make a summary plot for population proportions. Results: summary plot was meaningless

# mEos1xSummary = {} #{title: {1: %, 2: %, 3: %}, ...}
# for title, data in mEos1xData:
#     labels, counts = np.unique(data["manualLabel"], return_counts=True)
#     props = counts / sum(counts)
#     propDict = dict(zip(labels, props))
#     mEos1xSummary[title] = {0: propDict.get(0, 0), 1: propDict.get(1, 0), 2: propDict.get(2, 0)}

# mEos2xSummary = {} #{title: {1: %, 2: %, 3: %}, ...}
# for title, data in mEos2xData:
#     labels, counts = np.unique(data["manualLabel"], return_counts=True)
#     props = counts / sum(counts)
#     propDict = dict(zip(labels, props))
#     mEos2xSummary[title] = {0: propDict.get(0, 0), 1: propDict.get(1, 0), 2: propDict.get(2, 0)}

# mEos3xSummary = {} #{title: {1: %, 2: %, 3: %}, ...}
# for title, data in mEos3xData:
#     labels, counts = np.unique(data["manualLabel"], return_counts=True)
#     props = counts / sum(counts)
#     propDict = dict(zip(labels, props))
#     mEos3xSummary[title] = {0: propDict.get(0, 0), 1: propDict.get(1, 0), 2: propDict.get(2, 0)}

# mEos4xSummary = {} #{title: {1: %, 2: %, 3: %}, ...}
# for title, data in mEos4xData:
#     labels, counts = np.unique(data["manualLabel"], return_counts=True)
#     props = counts / sum(counts)
#     propDict = dict(zip(labels, props))
#     mEos4xSummary[title] = {0: propDict.get(0, 0), 1: propDict.get(1, 0), 2: propDict.get(2, 0)}

# plt.rcParams.update({'font.size': 12}) #make size reasonable for these plots


# plt.plot(mEos1xSummary.keys(), [val[0] for val in mEos1xSummary.values()], color=colors_decimal[0])
# plt.plot(mEos1xSummary.keys(), [val[1] for val in mEos1xSummary.values()], color=colors_decimal[1])
# plt.plot(mEos1xSummary.keys(), [val[2] for val in mEos1xSummary.values()], color=colors_decimal[2])
# plt.title("1x mEos (not final)")
# plt.ylabel("proportion")
# plt.xticks(rotation=20)
# plt.show()

# plt.plot(mEos2xSummary.keys(), [val[0] for val in mEos2xSummary.values()], color=colors_decimal[0])
# plt.plot(mEos2xSummary.keys(), [val[1] for val in mEos2xSummary.values()], color=colors_decimal[1])
# plt.plot(mEos2xSummary.keys(), [val[2] for val in mEos2xSummary.values()], color=colors_decimal[2])
# plt.title("2x mEos (not final)")
# plt.ylabel("proportion")
# plt.xticks(rotation=20)
# plt.show()

# plt.plot(mEos3xSummary.keys(), [val[0] for val in mEos3xSummary.values()], color=colors_decimal[0])
# plt.plot(mEos3xSummary.keys(), [val[1] for val in mEos3xSummary.values()], color=colors_decimal[1])
# plt.plot(mEos3xSummary.keys(), [val[2] for val in mEos3xSummary.values()], color=colors_decimal[2])
# plt.title("3x mEos (not final)")
# plt.ylabel("proportion")
# plt.xticks(rotation=20)
# plt.show()

# plt.plot(mEos4xSummary.keys(), [val[0] for val in mEos4xSummary.values()], color=colors_decimal[0])
# plt.plot(mEos4xSummary.keys(), [val[1] for val in mEos4xSummary.values()], color=colors_decimal[1])
# plt.plot(mEos4xSummary.keys(), [val[2] for val in mEos4xSummary.values()], color=colors_decimal[2])
# plt.title("4x mEos (not final)")
# plt.ylabel("proportion")
# plt.xticks(rotation=20)
# plt.show()

# plt.plot(mEos1xSummary.keys(), [val[1] for val in mEos1xSummary.values()])
# plt.plot(mEos2xSummary.keys(), [val[1] for val in mEos2xSummary.values()])
# plt.plot(mEos3xSummary.keys(), [val[1] for val in mEos3xSummary.values()])
# plt.plot(mEos4xSummary.keys(), [val[1] for val in mEos4xSummary.values()])
# plt.ylim((-0.1,1))
# plt.ylabel("proportion")
# plt.xticks(rotation=20)
# plt.legend(labels=["1x mEos", "2x mEos", "3x mEos", "4x mEos"])
# plt.title("only red populations")
# plt.show()

# plt.rcParams.update({'font.size': fontSize}) #reset to previous value

# %%
#add median +s

phaseMedianFig = plt.Figure((6.5,4), dpi=300)
phaseMedianAxs = phaseMedianFig.subplots(numRows,numCols)

NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos1xData, phaseMedianAxs[0], "manualLabel", hueOrder=[0,2,1], addTitles=False, firstColLabelsOnly=True, addXLabels=False, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos2xData, phaseMedianAxs[1], "manualLabel", hueOrder=[0,2,1], addTitles=False, firstColLabelsOnly=True, addXLabels=False, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos3xData, phaseMedianAxs[2], "manualLabel", hueOrder=[0,2,1], addTitles=False, firstColLabelsOnly=True, addXLabels=False, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos4xData, phaseMedianAxs[3], "manualLabel", hueOrder=[0,2,1], addTitles=False, firstColLabelsOnly=True, addXLabels=True, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)

#s is arm thickness, linewidths is arm length. I think they are drawing the lines in the short direction.
plusS = 0.5
plusLinewidths = 3.5

for i, (title, data) in enumerate(mEos1xData):
    for label in data["manualLabel"].unique():
        labelData = data[data["manualLabel"] == label]
        phaseMedianAxs[0,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

for i, (title, data) in enumerate(mEos2xData):
    for label in data["manualLabel"].unique():
        labelData = data[data["manualLabel"] == label]
        phaseMedianAxs[1,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

for i, (title, data) in enumerate(mEos3xData):
    for label in data["manualLabel"].unique():
        labelData = data[data["manualLabel"] == label]
        phaseMedianAxs[2,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

for i, (title, data) in enumerate(mEos4xData):
    for label in data["manualLabel"].unique():
        labelData = data[data["manualLabel"] == label]
        # phaseMedianAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=0.75, marker="+", s=plusS, linewidths=plusLinewidths)
        phaseMedianAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

reformatAxs(phaseMedianAxs)
phaseMedianFig.tight_layout(pad=0.25)
# phaseMedianFig.savefig("plots/valencySeries_phase_medianPlus.png", bbox_inches="tight")

phaseMedianFig

# %%
# #s is arm thickness, linewidths is arm length. I think they are drawing the lines in the short direction.
# plusS = 0.5
# plusLinewidths = 3

# #LIE: the plusses are not centered!!!!
# #TRUTH: I wasn't remaking the figure

# testFig = plt.Figure((6.5,4), dpi=300)
# testAxs = testFig.subplots(numRows,numCols-1)

# for i, (title, data) in enumerate(mEos1xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[0,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color="black", alpha=0.75, marker="+", s=plusS * 1.2, linewidths=plusLinewidths * 1.2)
#         testAxs[0,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos2xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[1,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color="black", alpha=0.75, marker="+", s=plusS * 1.2, linewidths=plusLinewidths * 1.2)
#         testAxs[1,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos3xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[2,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color="black", alpha=0.75, marker="+", s=plusS * 1.2, linewidths=plusLinewidths * 1.2)
#         testAxs[2,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos4xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color="black", alpha=0.75, marker="+", s=plusS * 1.2, linewidths=plusLinewidths * 1.2)
#         testAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=1, marker="+", s=plusS, linewidths=plusLinewidths)

# reformatAxs(testAxs)
# testFig.tight_layout(pad=0.25)
# testFig

# %%
# testFig = plt.Figure((6.5,4), dpi=300)
# testAxs = testFig.subplots(numRows,numCols-1)

# for i, (title, data) in enumerate(mEos1xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[0,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=0.75, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos2xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[1,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=0.75, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos3xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[2,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], alpha=0.75, marker="+", s=plusS, linewidths=plusLinewidths)

# for i, (title, data) in enumerate(mEos4xData[1:]):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         testAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal_darker[label], alpha=0.75, marker="+", s=plusS, linewidths=plusLinewidths)

# reformatAxs(testAxs)
# testFig.tight_layout(pad=0.25)
# testFig

# %%
# for color, color_darker in zip(colors_decimal, colors_decimal_darker):
#     print(np.array(color_darker) / np.array(color))

# %%
# phaseFig = plt.Figure((squarePlotSize*numCols ,squarePlotSize*numRows), dpi=300)
# phaseAxs = phaseFig.subplots(numRows,numCols, subplot_kw={'projection': "scatter_density"})
# NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos1xData, phaseAxs[0], "manualLabel", hueOrder=[0,2,1], addTitles=True, rowTitle="1x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
# NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos2xData, phaseAxs[1], "manualLabel", hueOrder=[0,2,1], addTitles=False, rowTitle="2x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
# NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos3xData, phaseAxs[2], "manualLabel", hueOrder=[0,2,1], addTitles=False, rowTitle="3x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)
# NanobodyPaperPlotting.BDFPAcceptorRowFromData(mEos4xData, phaseAxs[3], "manualLabel", hueOrder=[0,2,1], addTitles=False, rowTitle="4x mEos3", rowTitleXShift=-0.03, firstColLabelsOnly=True, xlims=expressionLims_kde, ylims=BDFPPositiveBDFPSSCLims_kde, emptyFirstCol=True, linewidths=None)


# for i, (title, data) in enumerate(mEos1xData):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         phaseAxs[0,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], s=12, alpha=0.75, linewidths=0)

# for i, (title, data) in enumerate(mEos2xData):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         phaseAxs[1,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], s=12, alpha=0.75, linewidths=0)

# for i, (title, data) in enumerate(mEos3xData):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         phaseAxs[2,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], s=12, alpha=0.75, linewidths=0)

# for i, (title, data) in enumerate(mEos4xData):
#     for label in data["manualLabel"].unique():
#         labelData = data[data["manualLabel"] == label]
#         phaseAxs[3,i].scatter(labelData["Acceptor/SSC"].median(), labelData["BDFP/SSC"].median(), color=colors_decimal[label], s=12, alpha=0.75, linewidths=0)



# phaseFig.tight_layout()
# # phaseFig.savefig("plots/valencySeries_phase_medianPoints_SMALLER.png")
# phaseFig

# %%
#TODO: delete this - it's not the real mEos series plot


# mEos1xControlData = NanobodyPaperPlotting.readDataFromFilelist(mEos1xFiles[0][1])
# mEos2xControlData = NanobodyPaperPlotting.readDataFromFilelist(mEos2xFiles[0][1])
# mEos3xControlData = NanobodyPaperPlotting.readDataFromFilelist(mEos3xFiles[0][1])
# mEos4xControlData = NanobodyPaperPlotting.readDataFromFilelist(mEos4xFiles[0][1])

# mEos1xControlData["mEosN"] = 1
# mEos2xControlData["mEosN"] = 2
# mEos3xControlData["mEosN"] = 3
# mEos4xControlData["mEosN"] = 4

# mEosSeriesData = pd.concat([mEos1xControlData, mEos2xControlData, mEos3xControlData, mEos4xControlData])

# %%
# # blueColors = ["", "#4A566A", "#2D5C78", "#3971A5", "#3FABFF"] #don't do shades of blue - too little contrast
# tab10 = plt.get_cmap("tab10")
# reorderedTab10 = ["", tab10(0), tab10(1), tab10(2), tab10(4)]

# fig = plt.Figure((squarePlotSize,squarePlotSize), dpi=300)
# ax = fig.add_subplot(projection = "scatter_density")

# # NanobodyPaperPlotting.plotDAmFRETClusters(combinedData["Acceptor/SSC"], combinedData["AmFRET"], combinedData["mEosN"], logX=True, colors=blueColors, xlims=expressionLims, ax=ax)
# # NanobodyPaperPlotting.plotDAmFRETClusters(combinedData["Acceptor/SSC"], combinedData["AmFRET"], combinedData["mEosN"], logX=True, colors=blueColors, ylims=(-0.2,0.6), xlims=expressionLims, ax=ax)
# NanobodyPaperPlotting.plotDAmFRETClusters(mEosSeriesData["Acceptor/SSC"], mEosSeriesData["AmFRET"], mEosSeriesData["mEosN"], logX=True, ylims=(-0.2,0.75), xlims=expressionLims, ax=ax, colors=reorderedTab10)

# for text in ax.texts:
#     text.set_visible(False)
    
# plt.show()
# # fig

# labels = ["4x mEos3", "3x mEos3", "2x mEos3", "1x mEos3"]

# textX = 0.01
# textYMax = 0.98
# #make the label for the highest pop
# label = labels[0]
# # higherText = ax.text(textX, textYMax, label, va="top", ha="left", color=blueColors[int(label[0])], transform = ax.transAxes)
# higherText = ax.text(textX, textYMax, label, va="top", ha="left", color=reorderedTab10[int(label[0])], transform = ax.transAxes)

# #make label for non-highest pop(s)
# for i, label in enumerate(labels[1:]):
#     # higherText = ax.annotate(label, xycoords=higherText, xy=(0,-1), color=blueColors[int(label[0])], horizontalalignment="left", transform = ax.transAxes)
#     higherText = ax.annotate(label, xycoords=higherText, xy=(0,-1), color=reorderedTab10[int(label[0])], horizontalalignment="left", transform = ax.transAxes)

# fig.tight_layout()
# # fig.savefig("plots/mEosSeries_SMALLER.png")
# fig
